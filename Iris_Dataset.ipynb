# %% [markdown]
# <a href="https://colab.research.google.com/github/jaasielmark12/AIML-TASK-3/blob/main/Iris_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Iris.csv")

# Drop Id column if present
if "Id" in df.columns:
    df.drop("Id", axis=1, inplace=True)

df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
numerical_features = df.select_dtypes(include=['float64']).columns

for feature in numerical_features:
    plt.figure()
    plt.hist(df[feature])
    plt.title(f"Distribution of {feature}")
    plt.xlabel(feature)
    plt.ylabel("Frequency")
    plt.show()

# %%
plt.figure()
df['Species'].value_counts().plot(kind='bar')
plt.title("Count Plot of Species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %%
for feature in numerical_features:
    plt.figure()
    plt.boxplot(df[feature])
    plt.title(f"Box Plot of {feature}")
    plt.ylabel(feature)
    plt.show()

# %%
plt.figure()
correlation_matrix = df[numerical_features].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df, hue="Species")
plt.show()
